# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/archive/Resume/Resume.csv')
print(df.shape)
df.head()
# Out:
# (2484, 4)
#          ID                                         Resume_str  \
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1  22323967           HR SPECIALIST, US HR OPERATIONS      ...
# 2  33176873           HR DIRECTOR       Summary      Over 2...
# 3  27018550           HR SPECIALIST       Summary    Dedica...
# 4  17812897           HR MANAGER         Skill Highlights  ...
#
#                                          Resume_html Category
# 0  <div class="fontsize fontface vmargins hmargin...       HR
# 1  <div class="fontsize fontface vmargins hmargin...       HR
# 2  <div class="fontsize fontface vmargins hmargin...       HR
# 3  <div class="fontsize fontface vmargins hmargin...       HR
# 4  <div class="fontsize fontface vmargins hmargin...       HR

# %%
print(df.columns.tolist())
df[['Category', 'Resume_str']].head(3)
# Out:
# ['ID', 'Resume_str', 'Resume_html', 'Category']
#   Category                                         Resume_str
# 0       HR           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1       HR           HR SPECIALIST, US HR OPERATIONS      ...
# 2       HR           HR DIRECTOR       Summary      Over 2...

# %%
print(df['Resume_str'].iloc[0][:1000])
# Out:
#          HR ADMINISTRATOR/MARKETING ASSOCIATE
#
# ...

# %%
import spacy
from spacy.matcher import PhraseMatcher
nlp = spacy.load("en_core_web_sm")

# %%
skills_list = [
     "Python", "Java", "SQL", "JavaScript", "React", "Node.js",
    "Machine Learning", "Data Analysis", "Project Management",
    "Customer Service", "Team Management", "Communication",
    "Leadership", "Excel", "Marketing", "Sales", "Accounting",
    "Nursing", "Teaching", "Design", "AWS", "Docker", "Git"
]
matcher = PhraseMatcher(nlp.vocab, attr='LOWER')
patterns = [nlp.make_doc(skill) for skill in skills_list]
matcher.add("SKILLS", patterns)

# %%
doc = nlp(df['Resume_str'].iloc[0])
matches = matcher(doc)
found_skills = set()
for match_id, start, end in matches:
    found_skills.add(doc[start:end].text.title())
print(found_skills)
# Out:
# {'Accounting', 'Leadership', 'Customer Service', 'Marketing', 'Team Management', 'Data Analysis', 'Design', 'Sales'}
